# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/mouse_metadata.csv"
study_results_path = "data/study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
#merge study_results, mouse_metadata

pharmacy_study = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])

# Display the data table for preview
pharmacy_study.head(2000)
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.

#calculate total # of mice
mouse_count = pharmacy_study["Mouse ID"].unique()
mouse_count = len(mouse_count)

# I did not get a list as the instructor mentions in the video but I already had the count of 249 with the data
#merged study_results, mouse_metadata so I guess that change didn't impact this block.

print("Number of mice:")
mouse_count
# Out:
# Number of mice:
# 249

# %%
pharmacy_study.duplicated(["Mouse ID", "Timepoint"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1888    False
# 1889    False
# 1890    False
# 1891    False
# 1892    False
# Length: 1893, dtype: bool

# %%
pharmacy_study[pharmacy_study.duplicated(["Mouse ID", "Timepoint"])]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
#Duplicates based on all columns.

pharmacy_study[pharmacy_study.duplicated(["Mouse ID", "Timepoint"], keep="first")]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
#Duplicate Rows except 1st occurrence
duplicate_pharmacy_studyDF = pharmacy_study[pharmacy_study.duplicated(["Mouse ID", "Timepoint"])]

print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicate_pharmacy_studyDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 

pharmacy_study[pharmacy_study.duplicated(['Mouse ID','Timepoint'],keep=False)]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# ...

# %%
# Drop duplicate rows 

# keep first duplicate row
result_df = pharmacy_study.drop_duplicates()
print('Result DataFrame:\n', result_df)
# Out:
# Result DataFrame:
#       Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# keep first duplicate row
clean_pharmacy_study_df = pharmacy_study.drop_duplicates()
print('Clean DataFrame:\n', clean_pharmacy_study_df)

clean_pharmacy_study = (result_df)
clean_pharmacy_study.head()
# Out:
# Clean DataFrame:
#       Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.


#calculate total # of mice
mouse_count = clean_pharmacy_study["Mouse ID"].unique()
mouse_count = len(mouse_count)
print("Number of mice:")
mouse_count
# Out:
# Number of mice:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a (Pandas)summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.
#do 5 separate groupby's where each one is doing a different stat function like mean() end up with 5 different variables - can name them mean, median, variance, standard deviation, and SEM. You want to pull out just the Tumor Volume (mm3) column. These will be series.
# 5 different Groupby's with the appropriate accumulating functions 

grouped_mean = clean_pharmacy_study.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
grouped_mean

grouped_median = clean_pharmacy_study.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
grouped_median

grouped_var = clean_pharmacy_study.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
grouped_var

grouped_std = clean_pharmacy_study.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
grouped_std

grouped_sem = clean_pharmacy_study.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]
grouped_sem

#create a pd.DataFrame It will be a dictionary where you enter each column heading (mean, median, var, standard deviation,
#SEM) as the key and the valuse will be the stat series you just created. Dictionary -{ mean:grouped_mean, 
#median:grouped_median, variance: grouped_var, standard diviation:grouped_std, and SEM: grouped_sem  }
#value in the data fram is going to be one of the stat series you just calculated (grouped_mean etc. 
#will pull in those values)

pharmacy_stats_df = pd.DataFrame({"mean": grouped_mean, "median": grouped_median, "var": grouped_var, 
                                  "standard deviation": grouped_std, "SEM": grouped_sem})
pharmacy_stats_df
# Out:
#                    mean     median        var  standard deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.368318  50.909965  42.278090            6.502160  0.514041
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
#Generate a (Pyplot)summary statistics table of mean, median, variance, standard deviation, and SEM of tumoer
#volume by drug regimen using agg function

grouped_clean_pharmacy_study = clean_pharmacy_study.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean","median", "var", "std", "sem"]})
grouped_clean_pharmacy_study
#print(grouped_clean_pharmacy_study)
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.368318  50.909965  42.278090  6.502160  0.514041
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a (Pandas) bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
# Key is to make use of the value_counts function
#Using your clean dataframe (missing g989) do a value_counts on "Drug Regimen" 
#Take the counts from value_counts and do a .plt (kind="bar")

#Creating the index

#drug_regimen_idx = pd.Index([grouped_clean_pharmacy_study]name = "Drug Regimen")  
#print(idx) 

# find the count of unique values in the index 
#idx.value_counts() 


#set x_axis = np.arange(len([""]))
#tick_locations = [value for value in x_axis]
#  .plt (kind="bar")


#Can dress up your charts with labels and legends etc.

# %%
Regimen_counts = clean_pharmacy_study["Drug Regimen"].value_counts()
plt.xlabel('"Drug Regimen"')
plt.ylabel('Mouse Counts')
Regimen_counts.plot(kind="bar")
plt.show()

# %%
Regimen_counts
# Out:
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Stelasyn     181
# Ceftamin     178
# Infubinol    178
# Propriva     160
# Name: Drug Regimen, dtype: int64

# %%
# Generate a (Pyplot) bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
#Pyplot way

Regimen_counts.plot(kind="bar")
plt.xlabel('"Drug Regimen"')
plt.ylabel('Mouse Counts')
plt.bar(Regimen_counts.index.values, Regimen_counts.values)
plt.show()


# plt.bar(counts.index.values, counts.values I THINK)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

Sex_counts = clean_pharmacy_study["Sex"].value_counts()

Sex_counts.plot(kind="pie",autopct="%1.1f%%")
plt.show()


#Using your clean DF do a value_counts on "Sex"
#Take the counts from value_counts and do a .plot(kind="pie")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

Sex_counts = clean_pharmacy_study["Sex"].value_counts()
plt.pie(Sex_counts.values,labels=Sex_counts.index.values,autopct='%1.1f%%')
plt.show()

# from the value_counts
# use counts.values
# for the labels, it's counts.index.value

# can look at it do some formatting on numbers add title etc.

#plt.pie()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin These are the 4 to use as list titles

# Start by getting the last (greatest) timepoint for each mouse

max_timepoint_df = max_timepoint.pd.DataFrame(["Mouse ID", "Timepoints"])
max_timepoint_df                                              
                                             
#"Capomulin","Ramicane", "Ceftamin", "Infubinol"],"Tumor Volume (mm3)":[Tumor Volume (mm3)]})
                                                                  

#Mouse ID    max Timepoint

#groupby mouse id 

#drug_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# We have examples of how to do these
# Create quartiles with outliers


###CHALLANGING!


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-35757d3bac34> in <module>
#       4 # Start by getting the last (greatest) timepoint for each mouse
#       5
# ----> 6 max_timepoint_df = max_timepoint.pd.DataFrame(["Mouse ID", "Timepoints"])
#       7 max_timepoint_df
#       8
#
# NameError: name 'max_timepoint' is not defined

# %%
# Put treatments into a list for for loop (and later for plot labels)

###CHALLANGING!

# Create empty list to fill with tumor vol data (for plotting)

volume_list

#inter quartile range, quantiles of .25, .75 IQR, Just copy the code and adapt it. 


# Calculate the IQR and quantitatively determine if there are any potential outliers.Take merged dataset from last block 

for drug in drug_list:  (DO EVERYTHING BELOW INSIDE THIS LOOP!)  
   
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # do a  .loc on that drug we're looping through and just pull out the tumor value mm3 column
  
    #Can do the boxplot with tumor value
    
    # add subset 
     #append the .loc value mm3 to the "volume_list" you created above -  volume_list.append(this_will_be_the_result_of_the_ .loc)
    
    # Determine outliers using upper and lower bounds  ()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

#then you can do a plt.boxplot (see example from activity but using the volumne list so you get 1 chart 
#with 4 box charts. If it doesnt work for you just do 4 boxplots)

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# shouldn't be difficult
#it's asking for any mouse id treated with Capomulin! Just pick a mouse id that is 

#follow example of code example we did for Line and Scatter Plots and Correlation and Regression

#need .lo to get the data. (2 .locs for columns and rows you need or 1 if you can do it and gather Campulin data for both variables)

# .loc (timepoint)
# .loc (tumor volume (mm3))

#plotting timepoint and tumer volume

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
#follow example of code example we did for Line and Scatter Plots and Correlation and Regression
